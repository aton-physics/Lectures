# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math
from Particle import Particle

# %%
run Particle.py

# %% [markdown]
# ## Problem 1

# %%
dragball = Particle(0, 100, 10000, 10, 10, 0.01, "High altitude, adiabatic pressure assumption")
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, tf = 10.0, dt = 0.001
dragball.scipy_trajectory()
dragball.plot()

constantdensityball = Particle(0, 100, 10000, 10, 10, 0.01, "Constant air density")
constantdensityball.scipy_trajectory(1)
constantdensityball.plot()

freeball = Particle(0, 100, 10000, 10, 10, 0.01, "No drag: free ball")
freeball.scipy_trajectory(2)
freeball.plot()
# Out:
# A new particle has been init'd
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# ## problem 1a
# The adiabatic model is very important in determining how far a launched ball may go. Since the drag force in any direction depends not only on the velocity in that direction, but also the magnitude of the total velocity, the launch angle also becomes very important. A large vertical velocity will incur a large drag force altering both the vertical and horizontal velocities. So a very large (near-vertical) angle is very terrible if the goal is to get a large horizontal distance before landing. Air is thinner in the higher altitudes, so there is less overall drag force; the ball goes farther. In the constant density approximation, the trajectory does not go as far since the drag force is larger. Finally, the ball in free fall goes furthest as expected, as the drag force is totally absent.
#
# ## problem 1b
#
# The mesosphere begins at about 50,000 meters above sea level. So we will use 60,000 meters as our initial altitude. Further, the adiabatic model breaks down at altitudes higher than 45,000 meters so we take the air density to be zero past this height. Also, the gravitational acceleration due to height can be given as $$a = GM/(R+h)^2$$
#
# where the variables take their usual definitions in Newtonian mechanics: a is acceleration, G is gravitational constant, M is the mass of the earth, R is the radius of the earth to the surface, and h is the altitude of our particle.

# %%
constantdensityball = Particle(0, 100, 50000, 10, 10, 0.01, "Constant air density")
constantdensityball.scipy_trajectory(1)
constantdensityball.plot()

freeball = Particle(0, 100, 50000, 10, 10, 0.01, "No drag: free ball")
freeball.scipy_trajectory(2)
freeball.plot()
# Out:
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# Clearly, gravitational acceleration's variation with height does not severely alter the particle's trajectory. Consider the equation for gravitational acceleration and this may be obvious: the earth is long relative to the distance between the surface and the mesosphere. R is about 6371 km, while the mesosphere sits at 50 km, so the perturbation to the height is one part in a hundred and can be neglected to a good approximation as we have shown.
#
# ## Problem 2 Note to self: these need to all be replotted once I get my integrator working. Consider rewriting the euler integrator because I've spent too much time on odeint
#
# ## Problem 2a
#
# I will assume the ball has radius 0.25 meters, and the dam is 100 meters high. Also, the ball has mass 1 kg and if it rotates, it rotates at 2 revolution per second (4*pi radians per second)

# %%
run Particle.py

# %%
damball = Particle3D(0, 0, 0, 0, 100, 1, 30, 0.01, "3d plot, thrown straight up with no backspin off a dam (no wind)", 0, 0, 0)
damball.RK4_trajectory()
damball.RK4_plot()
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z = 100.0, v_z0 = 0.0, tf = 10.0, dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0
# Out:
# A new particle has been init'd

# %%
#damball = Particle3D(0, 0, 0, 0, 100, 1, 100, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball = Particle3D(0, 0, 0, 0, 100, 1, 33, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball.RK4_trajectory()
damball.RK4_plot()
#damball.plot()
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z = 100.0, v_z0 = 0.0, tf = 10.0, dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0
# Out:
# A new particle has been init'd

# %%
damball = Particle3D(0, 0, 0, 1, 100, 0, 35, 0.01, "3d plot, thrown horizontally with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball.RK4_trajectory()
damball.RK4_plot()
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z = 100.0, v_z0 = 0.0, tf = 10.0, dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0
# Out:
# A new particle has been init'd

# %% [markdown]
# Cool - backspin with a horizontal throw curves even in the absence of wind. Backspin with a straight throw curves the trajectory away from the ground (compare to throwing up with no spin).
#
# Referring to the plot 'thrown straight up with backspin off a dam (no wind)', the basketball with my specified parameters goes about 25 meters before it hits the ground.
#
# ## Problem 2b

# %%
damball = Particle3D(0, 0, 0, 0, 100, 1, 35, 0.01, "3d plot, thrown vertically with side spin off a dam (no wind)", 0, 0, 4*3.14)
damball.RK4_trajectory()
damball.RK4_plot()
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z = 100.0, v_z0 = 0.0, tf = 10.0, dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0
damball2 = Particle3D(0, 0, 0, 1, 100, 1, 35, 0.01, "3d plot, thrown diagonally with side spin off a dam (no wind)", 0, 0, 4*3.14)
damball2.RK4_trajectory()
damball2.RK4_plot()
# Out:
# A new particle has been init'd
# A new particle has been init'd

# %%
run Particle.py

# %%
damball = Particle3D(0, 0, 0, 1, 100, 1, 35, 0.01, "3d plot, thrown vertically with side spin (1000 rpm) off a dam (no wind)", 0, 0, 200/6*3.14159)
damball.RK4_trajectory()
damball.RK4_plot()
# Out:
# A new particle has been init'd

# %% [markdown]
# When launched with side spin, the ball drops straight down unless it is thrown diagonally. When it is thrown diagonally, the ball arcs and lands very near to the initial position in x and y. And when the side spin is greater, the distance covered is even less as the arc is very severe and the ball does not make it very far before drag kills all of its acceleration. Note 1000 rpm = 200/6 * pi radians per second.
#
# ## Problem 2c
#
# We test energy conservation in the flight of the ball. To do so, I plot current energy, work due to drag, and initial energy minus work due to drag. The hope is that current energy and initial energy minus work due to drag are equal. Note that we have assumed constant angular velocity, so I neglect the body-rotational contribution to kinetic energy.
#
# First, a test of a ball in free fall (no drag, no lift). We will see that the total energy is conserved up to more than 10 parts in a million with a systematic nonzero drift. We expect this from classical mechanics (symplectic-ness of Hamilton's equations)

# %%
#damball = Particle3D(0, 0, 0, 0, 100, 1, 100, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball = Particle3D(0, 0, 0, 0, 100, 1, 20, 0.01, "No drag no lift, only gravity", 0, 0, 0)
damball.RK4_trajectory()
damball.RK4_plot()
#damball.plot()
damball.energy_conservation()
# Out:
# A new particle has been init'd

# %%
#damball = Particle3D(0, 0, 0, 0, 100, 1, 100, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball = Particle3D(0, 0, 0, 0, 100, 1, 33, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball.RK4_trajectory()
damball.RK4_plot()
damball.energy_conservation()
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z = 100.0, v_z0 = 0.0, tf = 10.0, dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0
# Out:
# A new particle has been init'd

# %% [markdown]
# So the work-energy theorem is valid for our simulation. Note this plot of energies pertains to the same simulation parameters as those in the previous question regarding backspin off a dam.
#
# ## Problem 2d
#
# It is probably not fair to assume constant angular velocity of our basketball. Note that if the (motion-opposing) torque is proportional to the angular velocity we have $$ \theta'' = -\theta'$$ which is solved by decaying exponentials (with a time constant and initial condition).
#
# I will explore the simplest exponential $$ \theta'(t) = \theta'_{o}e^{-t}$$

# %%
#damball = Particle3D(0, 0, 0, 0, 100, 1, 100, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball = Particle3D(0, 0, 0, 0, 100, 1, 33, 0.01, "3d plot, thrown straight up with backspin off a dam (no wind)", 0, 4*3.14, 0)
damball.RK4_trajectory()
damball.RK4_plot()
#x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z = 100.0, v_z0 = 0.0, tf = 10.0, dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0
# Out:
# A new particle has been init'd

# %% [markdown]
# As expected, an exponentially decaying rotational velocity means that the magnus force must also decay. I.e. the ball will lose its lift, and drag will make sure it plummets after some time. The ball is again thrown straight up with backspin, but this time it does not go nearly as far (less than 2 meters).
#
# Conclusion: The trajectory is very different for an exponentially decaying rotational velocity, so it is likely not fair to assume it is constant.

# %% [markdown]
# ## Problem 3
#
# The equation of motion for a charged particle in a magnetic field is given by $$\bf{a} = \rm \frac{q}{m} \bf{v} \times \bf{B}$$
#
# The strategy will be as follows. Defining the bottom left of the square to be the origin, charged particles will enter at (25 cm, 0 cm). We will assume they are positively charged - by symmetry, negatively charged particles will just fly in the opposite direction but the results will be the same. If the particle ever touches the top of the square (:, 50 cm) where : ranges from -30 to 25 cm, then it is not collected. We will assume for now that we have a multitude of detectors, so the particular y value between 0 and 50 cm does not matter, so long as it is within that range at x = -30 cm.
#
# For the given mass to charge ratios, we will conduct a simulation as such and report the strength of the field necessary for no particles to hit the top of the square. We select the plane of the square to be the x-y plane and completely neglect the z-direction. Since we are taking a cross product, we can let the B field be along z and note that all motion must occur in the x-y plane.

# %%
run Particle.py

# %%
masstocharge = [10]
b = [50, 75, 85]
for ii in range(len(b)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 10.0, 0.01, "Magnetic field = " + str(b[ii]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[0]))
    charge.set_masstocharge(masstocharge[0])
    charge.set_b(-b[ii]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d()
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# For the mass to charge ratio of 10, we need a field of 0.0085 Tesla.

# %%
masstocharge = [50]
b = [400, 450, 500]
for ii in range(len(b)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 10.0, 0.01, "Magnetic field = " + str(b[ii]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[0]))
    charge.set_masstocharge(masstocharge[0])
    charge.set_b(-b[ii]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d()
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# For a mass to charge ratio of 50, we need a field of about 0.045 Tesla.

# %%
masstocharge = [100]
b = [850, 900]
for ii in range(len(b)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 10.0, 0.01, "Magnetic field = " + str(b[ii]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[0]))
    charge.set_masstocharge(masstocharge[0])
    charge.set_b(-b[ii]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d()
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# For a mass to charge ratio of 100, we need a field of about 0.085 Tesla.

# %%
masstocharge = [1000]
b = [8500]
for ii in range(len(b)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 10.0, 0.01, "Magnetic field = " + str(b[ii]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[0]))
    charge.set_masstocharge(masstocharge[0])
    charge.set_b(-b[ii]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d()
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd

# %% [markdown]
# For a particle with mass to charge ratio of 1000, we need a field of about 0.85 Tesla.
#
# ## Problem 3b
#
# The mass to charge ratios in question are 40 and 45. An appropriate magnetic field for these ratios is about 0.045 Tesla based on our previous problem.

# %%
run Particle

# %%
masstocharge = [40, 45]
b = [400]
ylow = [0.37, 0.435]
yhigh = [0.375, 0.44]
for ii in range(len(masstocharge)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 1, 0.001, "Magnetic field = " + str(b[0]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[ii]))
    charge.set_masstocharge(masstocharge[ii])
    charge.set_b(-b[0]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d(1, -.3, -.29, ylow[ii], yhigh[ii])
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# We observe that the trajectories of the different particles differ by 6.8 centimeters.
#
# Now we increase the step size to learn how the trajectory is altered. Until now, we have used a very small step size which has been accurate, but perhaps excessive.

# %%
masstocharge = [40, 45]
b = [400]
ylow = [0.37, 0.435]
yhigh = [0.375, 0.44]
for ii in range(len(masstocharge)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 1, 0.1, "dt = " + str(0.1) + ", Magnetic field = " + str(b[0]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[ii]))
    charge.set_masstocharge(masstocharge[ii])
    charge.set_b(-b[0]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d(1, -.3, -.29, ylow[ii], yhigh[ii])
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# The step size we use here is 0.1 seconds. The one we have been using so far has been 0.001 seconds.
#
# We immediately see that at 0.1 second steps, the trajectory does not even fall within a tenth of a centimeter of our opening.

# %%
masstocharge = [40, 45]
b = [400]
ylow = [0.37, 0.435]
yhigh = [0.375, 0.44]
for ii in range(len(masstocharge)):
    charge = Particle3D(.25, 0.0, 0, 4, 0, 0, 0.5, 0.01, "dt = " + str(0.01) + ", Magnetic field = " + str(b[0]/(10**4)) + "Tesla, mass to charge ratio = " + str(masstocharge[ii]))
    charge.set_masstocharge(masstocharge[ii])
    charge.set_b(-b[0]) #if x goes east and y goes north, then z goes into you. I want z into the page, so I negate it.
    charge.RK4_trajectory()
    charge.plot2d(1, -.3, -.29, ylow[ii], yhigh[ii])
    
#def __init__(self, x0=0.0, v_x0=0.0,  y0=0.0, v_y0 = 0.0, z0 = 100.0, v_z0 = 0.0, tf = 10.0, 
#dt = 0.01, tag = "tag", omegax = 0.0, omegay = 0.0, omegaz = 0.0):
# Out:
# A new particle has been init'd
# A new particle has been init'd

# %% [markdown]
# We see that at 0.01 second steps, the trajectories are within a range of 1 micron of what we expect from 0.001 seconds.
#
# Then to get 0.1% accuracy we would want 6.8 cm / 10^4 size opening, so 6.8 microns wide. And the step size must be about 0.01 seconds or less.
